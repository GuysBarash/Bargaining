# %% [markdown]
# <a href="https://colab.research.google.com/github/GuysBarash/Bargaining/blob/main/BarganingGame_class_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/GuysBarash/Bargaining.git
# Out:
# fatal: destination path 'Bargaining' already exists and is not an empty directory.

# %%
from Bargaining.src.BargainGame import BargainGame

# %%
import sys
import pandas as pd
IN_COLAB = 'google.colab' in sys.modules

# %%
coalitions_value = dict()
coalitions_value['1_5'] = 1000
coalitions_value['1_2'] = 1000
coalitions_value['2_3'] = 1000
coalitions_value['3_4'] = 1000
coalitions_value['4_5'] = 1000

# %%
bargain_step = 50

# %%
game = BargainGame(bargain_step=bargain_step)
game.add_coalitions_from_dict(coalitions_value)
print(f"Players in game: {game.players_count}")
# Out:
# Players in game: 5

# %%
game.compile()

# %%
print(f"Roots detected: {len(game.roots)}")
# Out:
# Roots detected: 10

# %%
cycles, end_points = game.get_nontransient_points()
print(f"Cycles: {len(cycles)}")
print(f"DeadEnds: {len(end_points)}")
possible_endings = len(cycles) + len(end_points)
print(f"Possible endings: {possible_endings}")
# Out:
# Cycles: 27
# DeadEnds: 10
# Possible endings: 37

# %%
# Plot entire barganing process
game.plot_bargaining_graph(colab_mode=IN_COLAB)

# %%
# Print components
components = game.components
for idx, comp in enumerate(components):
    print(f'[{idx + 1}/{len(components)}]\t')
    for c in components[0]:
        print(c)
# Out:
# [1/11]
# (2)550_450_550_0_450
# (1)500_500_0_450_550
# (1)500_550_450_0_500
# (2)550_450_500_500_0
# (3)0_500_500_550_450
# (3)0_500_500_500_500
# (1)500_500_500_0_500
# (1)450_550_0_450_550
# (4)500_0_550_450_500
# (1)500_500_0_500_500
# (2)550_450_550_450_0
# (5)550_450_0_550_450
# (5)550_450_0_500_500
# (3)450_550_450_550_0
# (3)500_500_500_500_0
# (1)450_550_0_500_500
# (3)500_500_450_550_0
# (3)0_550_450_550_450
# (4)450_0_550_450_550
# (5)500_0_450_550_500
# (4)0_450_550_500_500
# (5)500_500_0_550_450
# (3)450_550_500_500_0
# (1)450_500_500_0_550
# (5)550_0_450_550_450
# (1)450_550_450_0_550
# (2)500_450_550_0_500
# (4)500_0_500_500_500
# (2)550_500_500_0_450
# (4)0_500_500_500_500
# (2)500_500_500_500_0
# (2)500_500_550_450_0
# (4)0_500_500_450_550
# (2)500_500_500_0_500
# (3)0_550_450_500_500
# (5)500_500_0_500_500
# (5)500_0_500_500_500
# (4)0_450_550_450_550
# (4)450_0_500_500_550
# (5)550_0_500_500_450
# [2/11]
# (2)550_450_550_0_450
# (1)500_500_0_450_550
# ...

# %%
# Plot negotiation final form
game.plot_bargaining_graph_non_transient(colab_mode=IN_COLAB)

# %%
from google.colab import data_table
histdf = game.random_walk_graph(normalize=False)
data_table.DataTable(histdf, include_index=True)
# Out:
# ...
# Random walk on component 2/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 2 was broken
# Random walk on component 3/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 3 was broken
# Random walk on component 4/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 4 was broken
# Random walk on component 5/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 5 was broken
# Random walk on component 6/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 6 was broken
# Random walk on component 7/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 7 was broken
# Random walk on component 8/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 8 was broken
# Random walk on component 9/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 9 was broken
# Random walk on component 10/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 10 was broken
# Random walk on component 11/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# ...

# %%
from google.colab import data_table
histdf = game.random_walk_graph(normalize=True)
data_table.DataTable(histdf.round(4), include_index=True)
# Out:
# ...
# Random walk on component 2/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 2 was broken
# Random walk on component 3/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 3 was broken
# Random walk on component 4/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 4 was broken
# Random walk on component 5/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 5 was broken
# Random walk on component 6/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 6 was broken
# Random walk on component 7/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 7 was broken
# Random walk on component 8/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 8 was broken
# Random walk on component 9/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 9 was broken
# Random walk on component 10/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# Component 10 was broken
# Random walk on component 11/11:   0%|          | 0/10000 [00:00<?, ?it/s]
# ...

# %%
data_table.DataTable(pd.DataFrame(game.ssdf))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>(3)0_500_500_550_450</th>
#       <td>0.025</td>
#     </tr>
#     <tr>
#       <th>(1)500_500_500_0_500</th>
#       <td>0.025</td>
#     </tr>
#     <tr>
#       <th>(1)450_550_0_450_550</th>
#       <td>0.025</td>
#     </tr>
#     <tr>
#       <th>(4)500_0_550_450_500</th>
#       <td>0.025</td>
#     </tr>
#     <tr>
#       <th>(5)550_450_0_550_450</th>
#       <td>0.025</td>
#     </tr>
#     <tr>
#       <th>(3)500_500_500_500_0</th>
#       <td>0.025</td>
#     </tr>
#     <tr>
#       <th>(3)450_550_450_550_0</th>
#       <td>0.025</td>
# ...
